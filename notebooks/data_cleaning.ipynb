# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("insurance_preprocessing.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data[["sex","charges"]].groupby(["sex"], as_index = False).mean().sort_values(by = "charges",ascending = False).style.background_gradient("Blues")
# Out:
# <style type="text/css">
# #T_98a8b_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_98a8b_row1_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_98a8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98a8b_level0_col0" class="col_heading level0 col0" >sex</th>
#       <th id="T_98a8b_level0_col1" class="col_heading level0 col1" >charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98a8b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_98a8b_row0_col0" class="data row0 col0" >male</td>
#       <td id="T_98a8b_row0_col1" class="data row0 col1" >13956.751178</td>
#     </tr>
#     <tr>
#       <th id="T_98a8b_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_98a8b_row1_col0" class="data row1 col0" >female</td>
#       <td id="T_98a8b_row1_col1" class="data row1 col1" >12569.578844</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.title("Average age by region", color = "purple")
plt.xlabel("regions")
plt.ylabel("age mean")
plt.subplot(3,2,2)
sns.barplot(x = genders, y = sexAgeMean, palette="binary")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\dell\Desktop\medical\medical\notebooks\data_cleaning.ipynb Cell 7 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/medical/medical/notebooks/data_cleaning.ipynb#ch0000006?line=2'>3</a> plt.ylabel("age mean")
#       <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/medical/medical/notebooks/data_cleaning.ipynb#ch0000006?line=3'>4</a> plt.subplot(3,2,2)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dell/Desktop/medical/medical/notebooks/data_cleaning.ipynb#ch0000006?line=4'>5</a> sns.barplot(x = genders, y = sexAgeMean, palette="binary")
#
# NameError: name 'genders' is not defined

# %%
data["smoker"] = [0 if i == "no" else 1 for i in data["smoker"]]

# %%
data
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0       1  southwest  16884.92400
# 1      18    male  33.770         1       0  southeast   1725.55230
# 2      28    male  33.000         3       0  southeast   4449.46200
# 3      33    male  22.705         0       0  northwest  21984.47061
# 4      32    male  28.880         0       0  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3       0  northwest  10600.54830
# 1334   18  female  31.920         0       0  northeast   2205.98080
# 1335   18  female  36.850         0       0  southeast   1629.83350
# 1336   21  female  25.800         0       0  southwest   2007.94500
# 1337   61  female  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data["sex"] = [0 if i == "no" else 1 for i in data["sex"]]

# %%
data
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    1  33.770         1       0  southeast   1725.55230
# 2      28    1  33.000         3       0  southeast   4449.46200
# 3      33    1  22.705         0       0  northwest  21984.47061
# 4      32    1  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    1  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data["region"] = [0 if i == "southeast" else 1 if i == "southwest" else 2 if i == "northwest" else 3 for i in data["region"]]

# %%
data
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       1       1  16884.92400
# 1      18    1  33.770         1       0       0   1725.55230
# 2      28    1  33.000         3       0       0   4449.46200
# 3      33    1  22.705         0       0       2  21984.47061
# 4      32    1  28.880         0       0       2   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       2  10600.54830
# 1334   18    1  31.920         0       0       3   2205.98080
# 1335   18    1  36.850         0       0       0   1629.83350
# 1336   21    1  25.800         0       0       1   2007.94500
# 1337   61    1  29.070         0       1       2  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   int64
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   int64
#  5   region    1338 non-null   int64
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %%
 data.to_csv(r'C:/Users/dell/Desktop/medical/medical/source_data/insurance.csv')
